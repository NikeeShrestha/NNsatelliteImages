# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle

# %%
df=pd.read_excel("Figure1/Figure1A/DateofCollection.xlsx")

# %%
df
# Out:
#            Location       Date      Image
# 0       Scottsbluff 2022-07-04  Satellite
# 1       Scottsbluff 2022-07-17  Satellite
# 2       Scottsbluff 2022-08-07  Satellite
# 3       Scottsbluff 2022-08-18  Satellite
# 4       Scottsbluff 2022-09-09  Satellite
# 5       Scottsbluff 2022-09-24  Satellite
# 6       Scottsbluff 2022-07-08        UAV
# 7       Scottsbluff 2022-07-22        UAV
# 8       Scottsbluff 2022-08-12        UAV
# 9      North Platte 2022-07-09  Satellite
# 10     North Platte 2022-07-17  Satellite
# 11     North Platte        NaT  Satellite
# 12     North Platte        NaT  Satellite
# 13     North Platte        NaT  Satellite
# 14     North Platte        NaT  Satellite
# 15     North Platte 2022-07-13        UAV
# 16     North Platte 2022-07-19        UAV
# 17     North Platte 2022-08-03        UAV
# 18          Lincoln 2022-07-18  Satellite
# 19          Lincoln 2022-08-06  Satellite
# 20          Lincoln 2022-09-03  Satellite
# 21          Lincoln 2022-09-11  Satellite
# 22          Lincoln 2022-09-19  Satellite
# 23          Lincoln 2022-09-27  Satellite
# 24          Lincoln 2022-07-13        UAV
# 25          Lincoln 2022-07-28        UAV
# 26          Lincoln 2022-08-04        UAV
# 27  Missouri Valley 2022-07-13  Satellite
# 28  Missouri Valley 2022-07-21  Satellite
# 29  Missouri Valley 2022-08-08  Satellite
# 30  Missouri Valley 2022-09-03  Satellite
# 31  Missouri Valley 2022-09-11  Satellite
# 32  Missouri Valley 2022-09-19  Satellite
# 33  Missouri Valley 2022-07-13        UAV
# 34  Missouri Valley 2022-07-27        UAV
# 35  Missouri Valley 2022-08-10        UAV
# 36             Ames 2022-07-15  Satellite
# 37             Ames 2022-07-23  Satellite
# 38             Ames 2022-08-10  Satellite
# 39             Ames 2022-08-31  Satellite
# 40             Ames 2022-09-11  Satellite
# 41             Ames 2022-09-24  Satellite
# 42             Ames        NaT        UAV
# 43             Ames        NaT        UAV
# 44             Ames        NaT        UAV
# 45    Crawfordville 2022-07-10  Satellite
# 46    Crawfordville 2022-07-20  Satellite
# 47    Crawfordville 2022-08-02  Satellite
# 48    Crawfordville 2022-09-13  Satellite
# 49    Crawfordville 2022-10-01  Satellite
# 50    Crawfordville 2022-10-09  Satellite
# 51    Crawfordville 2022-07-12        UAV
# 52    Crawfordville 2022-07-26        UAV
# 53    Crawfordville 2022-08-11        UAV

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans"
})
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 16,
       'color':"black"}

IZ_colors = ['#905020','#56B567']

fig = plt.figure(figsize=(10,10))
# gs = fig.add_gridspec(2,1)
ax1=fig.add_subplot(2,1,1)
sns.set_context(rc = {'patch.linewidth': 0, 'fontsize':12})
sns.set_theme(style="ticks", rc={"axes.grid": False})
sns.set_style({'axes.linewidth': 2,'axes.edgecolor': 'black'})


sns.stripplot(x=df["Location"], y=df['Date'], hue=df['Image'], dodge=True, jitter=0,s=15, marker='<', palette=IZ_colors)

ymin = df["Date"].min()
ymax =  df["Date"].max()
months = pd.date_range(start='2022-06-15', end='2022-10-15', freq='M')
month_names = [date.strftime('%B') for date in months]
plt.yticks(months,month_names)
y_padding = (ymax - ymin) * 0.05  # Adjust the padding factor as needed
plt.ylim(ymin - y_padding, ymax + y_padding)
plt.yticks(months, month_names)
# plt.xticks(rotation=45)
ax1 = plt.gca()
ax1.tick_params(axis='x', labeltop=True, labelbottom=False, which="both", bottom=False, top=False)

plt.vlines(x=[0,1,2,3,4,5], ymin=ymin- y_padding, ymax=ymax + y_padding, color="black", linewidth=2)

# plt.hlines(y=['2022-07-20','2022-07-30'], xmin=-0.5, xmax=0.5)


# plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.3, x2=0.3, color='brown', alpha=0.1)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)

plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.xlabel('')
plt.ylabel('')
ax1.invert_yaxis()
sns.despine(bottom = True, right=True, top=True)

# plt.show()
plt.show()

# plt.savefig("Figure1A.png", bbox_inches='tight', dpi=350)
# plt.savefig("Figure1A.svg", bbox_inches='tight',dpi=350)

##Floweirng time range in each location

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans"
})
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 16,
       'color':"black"}

IZ_colors = ['#905020','teal']

fig=plt.figure(figsize=(15,10))
fig.tight_layout(h_pad=2)
# gs = fig.add_gridspec(2,1)
ax1=fig.add_subplot(2,2,1)
sns.set_context(rc = {'patch.linewidth': 0, 'fontsize':12})
sns.set_theme(style="ticks", rc={"axes.grid": False})
sns.set_style({'axes.linewidth': 2,'axes.edgecolor': 'black'})


sns.stripplot(x=df["Location"], y=df['Date'], hue=df['Image'], dodge=True, jitter=0,s=15, marker='<', palette=IZ_colors)

ymin = df["Date"].min()
ymax =  df["Date"].max()
months = pd.date_range(start='2022-06-15', end='2022-10-15', freq='M')
month_names = [date.strftime('%B') for date in months]
plt.yticks(months,month_names)
y_padding = (ymax - ymin) * 0.05  # Adjust the padding factor as needed
plt.ylim(ymin - y_padding, ymax + y_padding)
plt.yticks(months, month_names)
# plt.xticks(rotation=45)
ax1 = plt.gca()
ax1.tick_params(axis='x', labeltop=True, labelbottom=False, which="both", bottom=False, top=False)

plt.vlines(x=[0,1,2,3,4,5], ymin=ymin- y_padding, ymax=ymax + y_padding, color="black", linewidth=2)

# plt.hlines(y=['2022-07-20','2022-07-30'], xmin=-0.5, xmax=0.5)


# plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.3, x2=0.3, color='brown', alpha=0.1)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)
# # plt.fill_betweenx(y=[pd.Timestamp('2022-07-20'), pd.Timestamp('2022-07-30')], x1=-0.5, x2=0.5, color='red', alpha=0.2)

plt.legend(bbox_to_anchor=(1,1), loc='upper right')
plt.xlabel('')
plt.ylabel('')
ax1.invert_yaxis()
sns.despine(bottom = True, right=True, top=False)

# plt.show()

locations=Finaldf.location.unique()
ax2=fig.add_subplot(2,2,2) 
IZ_colors = ['springgreen','darkgreen']
# Iterate over locations and overlay lmplot for each


for i, location in enumerate(locations):
    location_data = Finaldf[Finaldf['location'] == location]
    
    sns.set_context(rc={'patch.linewidth': 2, 'fontsize': 12,"font.family": "sans-serif","font.sans-serif": "Nimbus Sans"})
    sns.set_theme(style="ticks", rc={"axes.grid": False})
    sns.set_style({'axes.linewidth': 2, 'axes.edgecolor': 'black'})
    
    reg=sns.regplot(data=location_data, x='Green_mean', y='Green_mean_sat', label=location,color=IZ_colors[i % len(IZ_colors)])
    
    y_pred = location_data['Green_mean']  # Get the predicted values from the regression line
    y_true = location_data['Green_mean_sat']    # Get the actual values
    r,p = sp.stats.pearsonr(location_data['Green_mean'], location_data['Green_mean_sat'])
    
    r_squared = np.round(r*r, 2)        # Round to two decimal places
    
    # Annotate the plot with R-squared value
    if location=='Missouri Valley':
        x_coord = 110 # Choose x coordinate for annotation
        y_coord = 585  # Choose y coordinate for annotation
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12,fontname='Nimbus Sans')
    elif location=='Crawfordsville':
        x_coord = 142  # Choose x coordinate for annotation
        y_coord = 550
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12,fontname='Nimbus Sans')
    

# Set title and axis labels
# plt.title("Linear Regression Plot for Different Locations")
sns.despine(bottom = False, right=True, top=True)
plt.xlabel(r'Mean $\textit{Reflectance}_{\textit{green}}$ of UAV Images')
plt.ylabel(r'Mean $\textit{Reflectance}_{\textit{green}}$ of Satellite Images')
plt.legend()
# ax=plt.gca()
xticks=reg.get_xticks()
yticks=reg.get_yticks()

# reg.set_xticks(xticks)
reg.set_xticklabels([round(x) for x in xticks])
reg.set_yticklabels([round(y) for y in yticks])

########################################################3

locations=Finaldf.location.unique()
ax3=fig.add_subplot(2,2,3) 
IZ_colors = ['indianred','darkred']


for i, location in enumerate(locations):
    location_data = Finaldf[Finaldf['location'] == location]
    
    sns.set_context(rc={'patch.linewidth': 2, 'fontsize': 12,"font.family": "sans-serif","font.sans-serif": "Nimbus Sans"})
    sns.set_theme(style="ticks", rc={"axes.grid": False})
    sns.set_style({'axes.linewidth': 2, 'axes.edgecolor': 'black'})
    
    reg=sns.regplot(data=location_data, x='Red_mean', y='Red_mean_Sat', label=location,color=IZ_colors[i % len(IZ_colors)])
    
    y_pred = location_data['Red_mean']  # Get the predicted values from the regression line
    y_true = location_data['Red_mean_Sat']    # Get the actual values
    r,p = sp.stats.pearsonr(location_data['Red_mean'], location_data['Red_mean_Sat'])
    
    r_squared = np.round(r*r, 2)        # Round to two decimal places
    
    # Annotate the plot with R-squared value
    if location=='Missouri Valley':
        x_coord = 70  # Choose x coordinate for annotation
        y_coord = 410  # Choose y coordinate for annotation
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12)
    elif location=='Crawfordsville':
        x_coord = 108  # Choose x coordinate for annotation
        y_coord = 375
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12)
    

# Set title and axis labels
# plt.title("Linear Regression Plot for Different Locations")
sns.despine(bottom = False, right=True, top=True)
plt.xlabel(r'Mean $\textit{Reflectance}_{\textit{red}}$ of UAV Images')
plt.ylabel(r'Mean $\textit{Reflectance}_{\textit{red}}$ of Satellite Images')
plt.legend()

xticks=reg.get_xticks()
yticks=reg.get_yticks()

reg.set_xticklabels([round(x) for x in xticks])
reg.set_yticklabels([round(y) for y in yticks])

#########################################################
corrdf=pd.read_excel("Figure1/Correlation.xlsx", index_col=0)
ax3=fig.add_subplot(2,2,4) 
mask=corrdf.isnull()
sns.heatmap(corrdf, mask=mask, vmin=0, vmax=1, cmap="coolwarm", center=0,cbar_kws={'shrink': 0.6,'ticks':[0, .5, 1]})
ax = plt.gca()
ax.tick_params(axis='x', labeltop=True, labelbottom=False, which="both", bottom=False, top=False)
plt.xlabel("Days apart between Satellite and UAV images")
plt.yticks(rotation=0)



# plt.savefig("Figure1/Figure1.png", bbox_inches='tight', dpi=350)
plt.savefig("Figure1/Figure1.svg", bbox_inches='tight',dpi=350)
plt.show()

##Floweirng time range in each location
# Out:
# /tmp/ipykernel_226141/3239098039.py:99: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_xticklabels([round(x) for x in xticks])
# /tmp/ipykernel_226141/3239098039.py:100: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_yticklabels([round(y) for y in yticks])
# /tmp/ipykernel_226141/3239098039.py:145: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_xticklabels([round(x) for x in xticks])
# /tmp/ipykernel_226141/3239098039.py:146: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_yticklabels([round(y) for y in yticks])

# %%
# Crawfordsville=pd.read_csv("Data/Crawfordsville/UAV/RGBuav_Crawfordsville_TP1.csv")
# Crawfordsville=Crawfordsville[['file_','Red_mean','Green_mean']]
# Crawfordsville['location']='Crawfordsville'

# Crawfordsvillesat=pd.read_csv("Data/Crawfordsville/Satelliteimages/sixband/Sixband_Crawfordsville_TP1.csv")
# Crawfordsvillesat=Crawfordsvillesat[['file_','Red_mean','Green_mean']]
# Crawfordsvillesat.columns=['file_','Red_mean_Sat','Green_mean_sat']

# Crawfordsvilledf=pd.merge(Crawfordsville,Crawfordsvillesat, left_on='file_',right_on='file_',how="inner")

# %%
# MO=pd.read_csv("Data/Movalley/UAV/RGBuav_TP1.csv")
# MO=MO[['file_','Red_mean','Green_mean']]
# MO['location']='Missouri Valley'

# MOsat=pd.read_csv("Data/Movalley/Satelliteimages/sixband/SatelliteImage_6bands_TP1.csv")
# MOsat=MOsat[['file_','Red_mean','Green_mean']]
# MOsat.columns=['file_','Red_mean_Sat','Green_mean_sat']

# MOsatdf=pd.merge(MO,MOsat, left_on='file_',right_on='file_',how="inner")

# %%
# Finaldf=pd.concat([Crawfordsvilledf, MOsatdf], ignore_index = True)

# %%
Finaldf=pd.read_csv("Figure1/Figure1B/Df_ForFiguresBandC.csv")

# %%
locations=Finaldf.location.unique()
ax2=fig.add_subplot(2,1,2) 
IZ_colors = ['#905020','#56B567']
# Iterate over locations and overlay lmplot for each


for i, location in enumerate(locations):
    location_data = Finaldf[Finaldf['location'] == location]
    
    sns.set_context(rc={'patch.linewidth': 2, 'fontsize': 12,"font.family": "sans-serif","font.sans-serif": "Nimbus Sans"})
    sns.set_theme(style="ticks", rc={"axes.grid": False})
    sns.set_style({'axes.linewidth': 2, 'axes.edgecolor': 'black'})
    
    sns.regplot(data=location_data, x='Green_mean', y='Green_mean_sat', label=location,color=IZ_colors[i % len(IZ_colors)])
    
    y_pred = location_data['Green_mean']  # Get the predicted values from the regression line
    y_true = location_data['Green_mean_sat']    # Get the actual values
    r,p = sp.stats.pearsonr(location_data['Green_mean'], location_data['Green_mean_sat'])
    
    r_squared = np.round(r*r, 2)        # Round to two decimal places
    
    # Annotate the plot with R-squared value
    if location=='Missouri Valley':
        x_coord = 110 # Choose x coordinate for annotation
        y_coord = 585  # Choose y coordinate for annotation
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12,fontname='Nimbus Sans')
    elif location=='Crawfordsville':
        x_coord = 142  # Choose x coordinate for annotation
        y_coord = 550
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12,fontname='Nimbus Sans')
    

# Set title and axis labels
# plt.title("Linear Regression Plot for Different Locations")
sns.despine(bottom = False, right=True, top=True)
plt.xlabel(r'Mean $\textit{Reflectance}_{\textit{green}}$ of UAV Images')
plt.ylabel(r'Mean $\textit{Reflectance}_{\textit{green}}$ of Satellite Images')
plt.legend()
# ax=plt.gca()
xticks=reg.get_xticks()
yticks=reg.get_yticks()

# reg.set_xticks(xticks)
reg.set_xticklabels([round(x) for x in xticks])
reg.set_yticklabels([round(y) for y in yticks])
# plt.set_xticks(list(xticks), fontsize=12, fontname="Nimbus Sans")
# plt.yticks(list(yticks), fontsize=12, fontname="Nimbus Sans")



plt.savefig("Figure1/Figure1B/Figure1B.png", dpi=350)
plt.show()
# Out:
# /tmp/ipykernel_226141/2871041952.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_xticklabels([round(x) for x in xticks])
# /tmp/ipykernel_226141/2871041952.py:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_yticklabels([round(y) for y in yticks])

# %%
locations=Finaldf.location.unique()
ax3=fig.add_subplot(2,2,1) 
IZ_colors = ['#905020','#56B567']


for i, location in enumerate(locations):
    location_data = Finaldf[Finaldf['location'] == location]
    
    sns.set_context(rc={'patch.linewidth': 2, 'fontsize': 12,"font.family": "sans-serif","font.sans-serif": "Nimbus Sans"})
    sns.set_theme(style="ticks", rc={"axes.grid": False})
    sns.set_style({'axes.linewidth': 2, 'axes.edgecolor': 'black'})
    
    reg=sns.regplot(data=location_data, x='Red_mean', y='Red_mean_Sat', label=location,color=IZ_colors[i % len(IZ_colors)])
    
    y_pred = location_data['Red_mean']  # Get the predicted values from the regression line
    y_true = location_data['Red_mean_Sat']    # Get the actual values
    r,p = sp.stats.pearsonr(location_data['Red_mean'], location_data['Red_mean_Sat'])
    
    r_squared = np.round(r*r, 2)        # Round to two decimal places
    
    # Annotate the plot with R-squared value
    if location=='Missouri Valley':
        x_coord = 70  # Choose x coordinate for annotation
        y_coord = 410  # Choose y coordinate for annotation
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12)
    elif location=='Crawfordsville':
        x_coord = 108  # Choose x coordinate for annotation
        y_coord = 375
        plt.text(x_coord, y_coord, f'$R^2:{r_squared}$', fontsize=12)
    

# Set title and axis labels
# plt.title("Linear Regression Plot for Different Locations")
sns.despine(bottom = False, right=True, top=True)
plt.xlabel(r'Mean $\textit{Reflectance}_{\textit{red}}$ of UAV Images')
plt.ylabel(r'Mean $\textit{Reflectance}_{\textit{red}}$ of Satellite Images')
plt.legend()

xticks=reg.get_xticks()
yticks=reg.get_yticks()

reg.set_xticklabels([round(x) for x in xticks])
reg.set_yticklabels([round(y) for y in yticks])

plt.savefig("Figure1/Figure1B/Figure1C.png", dpi=350)
plt.show()
# Out:
# /tmp/ipykernel_226141/3011331675.py:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_xticklabels([round(x) for x in xticks])
# /tmp/ipykernel_226141/3011331675.py:43: UserWarning: FixedFormatter should only be used together with FixedLocator
#   reg.set_yticklabels([round(y) for y in yticks])

# %%
Crawfordsville=pd.read_csv("Data/Scottsbluff/UAV/RGBuav_TP2 (copy).csv")
Crawfordsville=Crawfordsville[['file_','Green_mean']]
Crawfordsville['location']='Crawfordsville'

Crawfordsvillesat=pd.read_csv("Data/Scottsbluff/Satelliteimages/sixband/SatelliteImage_6bands_TP1.csv")
Crawfordsvillesat=Crawfordsvillesat[['file_','Green_mean']]
Crawfordsvillesat.columns=['file_','Green_mean_sat']

Crawfordsvilledf=pd.merge(Crawfordsville,Crawfordsvillesat, left_on='file_',right_on='file_',how="inner")

# %%
Crawfordsvilledf
# Out:
#                           file_  Green_mean        location  Green_mean_sat
# 0    Scottsbluff-TP1-n150_10_10  159.450829  Crawfordsville     1265.310000
# 1    Scottsbluff-TP1-n150_10_11  161.221835  Crawfordsville     1298.788889
# 2    Scottsbluff-TP1-n150_10_12  155.251670  Crawfordsville     1213.900000
# 3    Scottsbluff-TP1-n150_10_13  155.359695  Crawfordsville     1195.066667
# 4    Scottsbluff-TP1-n150_10_14  155.924001  Crawfordsville     1273.500000
# ..                          ...         ...             ...             ...
# 515     Scottsbluff-TP1-n75_9_4  158.387916  Crawfordsville     1175.044444
# 516     Scottsbluff-TP1-n75_9_5  158.145158  Crawfordsville     1196.044444
# 517     Scottsbluff-TP1-n75_9_6  157.834888  Crawfordsville     1186.877778
# 518     Scottsbluff-TP1-n75_9_7  154.049838  Crawfordsville     1220.241758
# 519     Scottsbluff-TP1-n75_9_8  159.355119  Crawfordsville     1268.000000
#
# [520 rows x 4 columns]

# %%
y_pred = Crawfordsvilledf['Green_mean']  # Get the predicted values from the regression line
y_true = Crawfordsvilledf['Green_mean_sat']    # Get the actual values
r,p = sp.stats.pearsonr(y_pred, y_true)
r_squared = np.round(r*r, 2)   

print(r_squared,p)
# Out:
# 0.04 1.5123865882626624e-05

# %%
df=pd.read_excel("Figure1/Correlation.xlsx", index_col=0)

# %%
df=pd.read_excel("Figure1/Correlation.xlsx", index_col=0)

mask=df.isnull()
sns.heatmap(df, mask=mask, vmin=0, vmax=1, cmap="coolwarm", center=0,cbar_kws={'shrink': 0.6,'ticks':[0, .5, 1]})
ax = plt.gca()
ax.tick_params(axis='x', labeltop=True, labelbottom=False, which="both", bottom=False, top=False)
plt.yticks(rotation=0)

plt.show()

# %%
df=pd.read_excel("Figure1/Correlation.xlsx",sheet_name="Sheet2", index_col=0)

# %%
mask=df.isnull()
sns.heatmap(df, mask=mask, vmin=0, vmax=1, cmap="coolwarm", center=0,cbar_kws={'shrink': 0.6,'ticks':[0, .5, 1]})
ax = plt.gca()
ax.tick_params(axis='x', labeltop=True, labelbottom=False, which="both", bottom=False, top=False)
plt.yticks(rotation=0)

plt.show()
