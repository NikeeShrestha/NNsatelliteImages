# %%
import os
import sys
import seaborn as sns
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std

# %%
inputpath="../GenePrediction_files/Data_All/"
for item in os.listdir(inputpath):
    subdir=os.path.join(inputpath, item)
    
    print(subdir)
# Out:
# ../GenePrediction_files/Data_All/gene_exp_features
# ../GenePrediction_files/Data_All/nuc_seq_features
# ../GenePrediction_files/Data_All/categorical.txt
# ../GenePrediction_files/Data_All/codon
# ../GenePrediction_files/Data_All/chrom_states_features
# ../GenePrediction_files/Data_All/prot_exp_features
# ../GenePrediction_files/Data_All/pep_seq_features
# ../GenePrediction_files/Data_All/struc_dis_features
# ../GenePrediction_files/Data_All/label.txt

# %%
df=pd.read_csv("../GenePrediction_files/Data_All/gene_exp_features/gene_exp.txt", sep='\t')

# %%
df
# Out:
#                     ID  rmr6_leaf_control_T0  rmr6_leaf_control_T7  \
# 0      Zm00001eb000010              6.397830              6.685270
# 1      Zm00001eb000020              8.267065              8.232455
# 2      Zm00001eb000050                   NaN                   NaN
# 3      Zm00001eb000060              6.928265              6.680620
# 4      Zm00001eb000070              0.135694              0.156389
# ...                ...                   ...                   ...
# 39751  Zm00001eb442990                   NaN                   NaN
# 39752  Zm00001eb443000              0.587521              0.509653
# 39753  Zm00001eb443010                   NaN                   NaN
# 39754  Zm00001eb443020                   NaN                   NaN
# 39755  Zm00001eb443030              0.289492              0.412446
#
#        rmr6_leaf_drought_salt_T0  rmr6_leaf_drought_salt_T7  \
# 0                       7.283640                   6.044070
# ...

# %%
df.describe()
# Out:
#        rmr6_leaf_control_T0  rmr6_leaf_control_T7  rmr6_leaf_drought_salt_T0  \
# count          33516.000000          33112.000000               33361.000000
# mean               9.919508              9.793699                   9.286187
# std               52.207344             46.699206                  40.383884
# min                0.000101              0.000100                   0.000101
# 25%                0.411372              0.444621                   0.415601
# 50%                2.119416              2.185917                   2.100595
# 75%                7.368805              7.609960                   7.542685
# max             3442.300000           3151.866500                2667.200000
#
#        rmr6_leaf_drought_salt_T7  rmr6_leaf_drought_T0  rmr6_leaf_drought_T7  \
# count               34111.000000          33415.000000          33450.000000
# mean                    9.852359              9.456433             10.076265
# ...

# %%
df=pd.read_csv("../GenePrediction_files/Data_All/struc_dis_features/struc_dis.txt", sep='\t')

# %%
# df = df.drop_duplicates(subset=['ID'])

# %%
df
# Out:
#                     ID  dis_to_cen  dis_to_Knob  dis_to_telo  mRNAlength  \
# 0      Zm00001eb000010   137615089        29098     409600.0        5588
# 1      Zm00001eb000020   137608512        35675     403022.0        5549
# 2      Zm00001eb000050   137541032       103155     335542.0        5829
# 3      Zm00001eb000060   137463430       180757     257940.0        1023
# 4      Zm00001eb000070   137457988       186199     252498.0        8641
# ...                ...         ...          ...          ...         ...
# 39751  Zm00001eb442990           0            0          NaN        1072
# 39752  Zm00001eb443000           0            0          NaN         830
# 39753  Zm00001eb443010           0            0          NaN        3762
# 39754  Zm00001eb443020           0            0          NaN        3762
# 39755  Zm00001eb443030           0            0          NaN        1891
#
#        CDSlength  exonLength  exonNum  avgExonLength  UTR5length   distance  \
# ...

# %%
df.describe()
# Out:
#          dis_to_cen   dis_to_Knob   dis_to_telo     mRNAlength     CDSlength  \
# count  3.975600e+04  3.975600e+04  3.604700e+04   39756.000000  39756.000000
# mean   7.449135e+07  3.816677e+07  5.956530e+07    4240.680602   1088.868322
# std    3.873141e+07  5.323601e+07  6.262357e+07    6148.169933    845.708710
# min    0.000000e+00  0.000000e+00  1.288000e+03     213.000000     87.000000
# 25%    4.394134e+07  6.241602e+06  1.169718e+07    1216.000000    498.000000
# 50%    7.608161e+07  1.589851e+07  3.592978e+07    2633.000000    882.000000
# 75%    1.035907e+08  4.059078e+07  8.701321e+07    4850.000000   1425.000000
# max    1.706702e+08  2.370174e+08  2.429171e+08  299070.000000  16278.000000
#
#          exonLength       exonNum  avgExonLength    UTR5length      distance  \
# count  39756.000000  39756.000000   39756.000000  39756.000000  3.975600e+04
# mean    1570.261495      4.890079     543.573800    198.122673 -1.006879e+07
# ...

# %%
count=0
for c in df.columns:
    # print(df[c].count())
    if df[c].count() <39756 or df[c].count() >39756:
        print(c, df[c].count())
        count+=1
        df=df.drop(c,axis=1)
    # print(c)
    # print(df[c].count())
df.to_csv("../GenePrediction_files/Data_filtered/struc_dis_filtered.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/prot_exp_filtered.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/tri_pep_39755_noduplicates.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/Quasi_pep_39755.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/Pseudo_pep_39755.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/mono_pep_39755.txt", sep='\t', index=0) 
# df.to_csv("../GenePrediction_files/Data_filtered/Geary_pep_39755.txt", sep='\t', index=0)  
# df.to_csv("../GenePrediction_files/Data_filtered/CTriad_pep_39755.txt", sep='\t', index=0)  
# df.to_csv("../GenePrediction_files/Data_filtered/CTD_pep_39755.txt", sep='\t', index=0)  
# df.to_csv("../GenePrediction_files/Data_filtered/tri_nuc_filternotneeded.txt", sep='\t', index=0)  
# df.to_csv("../GenePrediction_files/Data_filtered/norm_tri_nuc_filternotneeded.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/norm_di_nuc_filternotneeded.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/di_nuc_filternotneeded.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/auto_nuc_filternotneeded.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/gene_expfiltered.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/count_filternotneede.txt", sep='\t', index=0)
# df.to_csv("../GenePrediction_files/Data_filtered/many_col_data_filtered.txt", sep='\t', index=0)
print(count)
# Out:
# dis_to_telo 36047
# 1
