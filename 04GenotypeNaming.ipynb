# %%
import pandas as pd
import numpy as np
import os
import math

# %%
datadf=pd.read_csv("Data/HYBRID_HIPS_V3.5_ALLPLOTS.csv")

# %%
datadf['location'].value_counts()
# Out:
# location
# North Platte3      638
# North Platte1      560
# North Platte2      560
# Ames               536
# Lincoln            532
# Scottsbluff        525
# Crawfordsville     522
# Missouri Valley    176
# Name: count, dtype: int64

# %%
# datadf_subset['range'].value_counts()

# %%
datadf_subset=datadf_subset.sort_values('row')
datadf_subset['row'].value_counts()
# Out:
# row
# 46    34
# 45    34
# 44    34
# 43    34
# 42    34
# 16    22
# 20    22
# 19    22
# 18    22
# 17    22
# 2     22
# 3     22
# 14    22
# 13    22
# 9     22
# 8     22
# 7     22
# 6     22
# 5     22
# 4     22
# 15    22
# Name: count, dtype: int64

# %%
satdf['row'].value_counts()
# Out:
# row
# 5     56
# 6     56
# 7     56
# 2     54
# 4     54
# 3     52
# 22    31
# 21    31
# 20    31
# 19    31
# 18    31
# 17    31
# 1     25
# 10    25
# 11    25
# 12    25
# 8     25
# 9     25
# Name: count, dtype: int64

# %%
datadf['range_row']=datadf['range'].astype(str)+'_'+datadf['row'].astype(str)+'_'+datadf['nitrogenTreatment'].astype(str)

# %%
path='/home/schnablelab/Documents/NNSatelliteImages/Data/'

# %%
# for index2, row2 in datadf.iterrows():
#     genotype=row2['genotype']
#     if row2['location']=='Crawfordsville':
#         # print(row2["experiment"])
#         field2=int(row2["experiment"].split("_")[1])
        # print(field2)

# %%
# mainfolder=os.listdir(path)

# for mainfolders in mainfolder:
#     if not mainfolders.endswith('.csv'):
#         mainfolderspath=os.path.join(path,mainfolders)
#         location=os.path.basename(mainfolderspath)
        
        
#         datadf_subset=datadf.loc[datadf['location']==str(location),]
#         print(datadf_subset['location'].value_counts())
#         # print(location)
#         subfolder=os.listdir(mainfolderspath)
#         for subfolders in subfolder:
            
#             if subfolders=='Satelliteimages':
#                 satfolderpath=os.path.join(mainfolderspath,subfolders)
                
#                 bothsat=os.listdir(satfolderpath)
                
#                 for finalfolder in bothsat:
#                     finalfolderpath=os.path.join(satfolderpath, finalfolder)
                    
#                     sattimepoints=os.listdir(finalfolderpath)
#                     j=1
#                     for file in sattimepoints:
#                         filepath=os.path.join(finalfolderpath,file)
#                         basename=os.path.basename(filepath).split('.')[0]
                        
#                         satdf=pd.read_csv(filepath)
#                         j+=1

#                         i=1
#                         for index1, row1 in satdf.iterrows():
#                             file=row1['field']
#                             field=int(file.split("-")[2].split('n')[1])
#                             print(field)
#                             try:
#                                 range1 = int(row1["range"])
#                             except ValueError:
#                                 print(f"Unable to convert 'range1' for index {index1} to an integer.")
#                                 continue
#                             # print(range1)
#                             rownum=int(row1["row"])
#                             # print(rownum)
#                             i+=1
#                             print(i)
#                             for index2, row2 in datadf.iterrows():
#                                 genotype=row2['genotype']
#                                 if location=='Crawfordsville' or location=='Ames' or location =='Movalley':
#                                     field2=row2["experiment"].split("_")[1]
#                                     # print(field2)
#                                     range2=int(row2["range"])
#                                     row_2=int(row2["row"])
#                                     # if 
                                
#                                 elif location=='Scottsbluff' or location=='Lincoln':
#                                     range2=int(row2["range"])
#                                     row_2=int(row2["row"])
#                                     # if row2['poundsOfNitrogenPerAcre']
                                    
# #                                     if math.nan(int(row2['poundsOfNitrogenPerAcre'])):
# #                                         continue
#                                     nitrogen=int(row2['poundsOfNitrogenPerAcre'])
#                                     # print(nitrogen)
#                                     if range1==range2 and rownum==row_2 and field==nitrogen:
#                                         # print(row2["genotype"])
#                                         satdf.at[index1, "genotype"]=genotype
                        
                        
#                         satdf.to_csv(f'{finalfolderpath}/{basename}_genotype.csv')
                        
#                 for finalfolder in bothsat:
#                     finalfolderpath=os.path.join(satfolderpath, finalfolder)
                    
#                     sattimepoints=os.listdir(finalfolderpath)
#                     j=1
#                     for file in sattimepoints:
#                         filepath=os.path.join(finalfolderpath,file)
#                         basename=os.path.basename(filepath).split('.')[0]
                        
#                         satdf=pd.read_csv(filepath)
#                         j+=1

#                         i=1
#                         for index1, row1 in satdf.iterrows():
#                             file=row1['field']
#                             field=int(file.split("-")[2].split('n')[1])
#                             print(field)
#                             try:
#                                 range1 = int(row1["range"])
#                             except ValueError:
#                                 print(f"Unable to convert 'range1' for index {index1} to an integer.")
#                                 continue
#                             # print(range1)
#                             rownum=int(row1["row"])
#                             # print(rownum)
#                             i+=1
#                             print(i)
#                             for index2, row2 in datadf.iterrows():
#                                 genotype=row2['genotype']
#                                 if location=='Crawfordsville' or location=='Ames' or location =='Movalley':
#                                     field2=row2["experiment"].split("_")[1]
#                                     # print(field2)
#                                     range2=int(row2["range"])
#                                     row_2=int(row2["row"])
#                                     # if 
                                
#                                 elif location=='Scottsbluff' or location=='Lincoln':
#                                     range2=int(row2["range"])
#                                     row_2=int(row2["row"])
#                                     # if row2['poundsOfNitrogenPerAcre']
                                    
# #                                     if math.nan(int(row2['poundsOfNitrogenPerAcre'])):
# #                                         continue
#                                     nitrogen=int(row2['poundsOfNitrogenPerAcre'])
#                                     # print(nitrogen)
#                                     if range1==range2 and rownum==row_2 and field==nitrogen:
#                                         # print(row2["genotype"])
#                                         satdf.at[index1, "genotype"]=genotype
                        
                        
#                         satdf.to_csv(f'{finalfolderpath}/{basename}_genotype.csv')

# %%
mainfolder=os.listdir(path)

for mainfolders in mainfolder:
    if not mainfolders.endswith('.csv'):
        mainfolderspath=os.path.join(path,mainfolders)
        location=os.path.basename(mainfolderspath)
        if not location=='Movalley':
            continue
        if location=='Movalley':
            location='Missouri Valley'
            
        
        datadf_subset=datadf.loc[datadf['location']==str(location),]
        print(datadf_subset['location'].value_counts())
        # print(location)
        subfolder=os.listdir(mainfolderspath)
        for subfolders in subfolder:
            
            if subfolders=='Satelliteimages':
                # continue
                satfolderpath=os.path.join(mainfolderspath,subfolders)
                
                bothsat=os.listdir(satfolderpath)
                
                
                for finalfolder in bothsat:
                    if not finalfolder=='sixband': ##Only sixband taking
                        continue
                    finalfolderpath=os.path.join(satfolderpath, finalfolder)
                    
                    sattimepoints=os.listdir(finalfolderpath)
                    j=0
                    for file in sattimepoints:
                        print(f'sat: {file}')
                        filepath=os.path.join(finalfolderpath,file)
                        
                        
                        basename=os.path.basename(filepath).split('.')[0]
                        
                        satdf=pd.read_csv(filepath)
                        
                        satdf['file_'] = satdf['file_'].str.replace('V2', '')
                        
                        satdf[['field', 'range', 'row']]=satdf["file_"].str.split('_', expand=True)
                        satdf['exp']=satdf["file_"].str.split('_', expand=True)[0].str.split('-', expand=True)[2]
                        j+=1

                        i=1
                        for index1, row1 in satdf.iterrows():
                            file=row1['field']
                            
                            
                            try:
                                range1 = int(row1["range"])
                            except ValueError:
                                print(f"Unable to convert 'range1' for index {index1} to an integer.")
                                continue
                            # print(range1)
                            rownum=int(row1["row"])
                            # print(rownum)
                            i+=1
                            # print(i)
                            for index2, row2 in datadf_subset.iterrows():
                                genotype=row2['genotype']
                                if location=='Crawfordsville' or location=='Ames':
                                    # print(row1['exp'])
                                    # print(location)
                                    exp=int(row1['exp'])
                                    if not 'LC'in row2["experiment"]:
                                        continue
                                    # print(row2["experiment"])
                                    field2=int(row2["experiment"].split("_")[1])
                                    # print(field2)
                                    range2=int(row2["range"])
                                    row_2=int(row2["row"])
                                    if range1==range2 and rownum==row_2 and exp==field2:
                                        satdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                        satdf.at[index1, 'combineYield']=row2["combineYield"]
                                        satdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                        satdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                        satdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                        satdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                        satdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                        satdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                        satdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                        satdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                        satdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                        satdf.at[index1, 'percentOil']=row2["percentOil"]
                                        satdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                        satdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                        satdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                        satdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                        satdf.at[index1, "genotype"]=genotype

                                
                                elif location=='Scottsbluff':
                                    # print(file)
                                    field=int(file.split("-")[2].split('n')[1])
                                    range2=int(row2["range"])
                                    row_2=int(row2["row"])
                                    # if row2['poundsOfNitrogenPerAcre']
                                    
#                                     if math.nan(int(row2['poundsOfNitrogenPerAcre'])):
#                                         continue
                                    nitrogen=int(row2['poundsOfNitrogenPerAcre'])
                                    # print(nitrogen)
                                    if range1==range2 and rownum==row_2 and field==nitrogen:
                                        # print(row2["genotype"])
                                        satdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                        satdf.at[index1, 'combineYield']=row2["combineYield"]
                                        satdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                        satdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                        satdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                        satdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                        satdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                        satdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                        satdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                        satdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                        satdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                        satdf.at[index1, 'percentOil']=row2["percentOil"]
                                        satdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                        satdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                        satdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                        satdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                        satdf.at[index1, "genotype"]=genotype
                                elif location=='Lincoln':
                                    range2=int(row2["range"])
                                    row_2=int(row2["row"])
                                    
                                    
                                    if range1==range2 and rownum==row_2:
                                        satdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                        satdf.at[index1, 'combineYield']=row2["combineYield"]
                                        satdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                        satdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                        satdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                        satdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                        satdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                        satdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                        satdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                        satdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                        satdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                        satdf.at[index1, 'percentOil']=row2["percentOil"]
                                        satdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                        satdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                        satdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                        satdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                        satdf.at[index1, "genotype"]=genotype
                                        
                                elif location =='Missouri Valley':
                                    range2=int(row2["row"])
                                    row_2=int(row2["range"])
                                    
                                    
                                    if range1==range2 and rownum==row_2:
                                        satdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                        satdf.at[index1, 'combineYield']=row2["combineYield"]
                                        satdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                        satdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                        satdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                        satdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                        satdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                        satdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                        satdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                        satdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                        satdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                        satdf.at[index1, 'percentOil']=row2["percentOil"]
                                        satdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                        satdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                        satdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                        satdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                        satdf.at[index1, "genotype"]=genotype
                                    
                        
                        print(j)
                        satdf.to_csv(f'{finalfolderpath}/{basename}_genotype.csv', index=False)
            elif subfolders=='UAV':
                # continue
                uavfolderpath=os.path.join(mainfolderspath,subfolders)
                
                bothsat=os.listdir(uavfolderpath)
                # print(bothsat)

                for file in bothsat:
                    print(f'UAV: {file}')
                    filepath=os.path.join(uavfolderpath,file)
                    # print(filepath)
                    basename=os.path.basename(filepath).split('.')[0]

                    uavdf=pd.read_csv(filepath)
                    uavdf['file_'] = uavdf['file_'].str.replace('V2', '')
                    uavdf[['field', 'range', 'row']]=uavdf["file_"].str.split('_', expand=True)
                    uavdf['exp']=uavdf["file_"].str.split('_', expand=True)[0].str.split('-', expand=True)[2]
                    
                    j+=1

                    i=1
                    for index1, row1 in uavdf.iterrows():
                        file=row1['field']
                        
                        # print(field)
                        try:
                            range1 = int(row1["range"])
                        except ValueError:
                            print(f"Unable to convert 'range1' for index {index1} to an integer.")
                            continue
                        # print(range1)
                        rownum=int(row1["row"])
                        # print(rownum)
                        i+=1
                        # print(i)
                        for index2, row2 in datadf_subset.iterrows():
                            genotype=row2['genotype']
                            if location=='Crawfordsville' or location=='Ames':
                                # print(row1['exp'])
                                # print(location)
                                exp=int(row1['exp'])
                                if not 'LC'in row2["experiment"]:
                                    continue
                                # print(row2["experiment"])
                                field2=int(row2["experiment"].split("_")[1])
                                # print(field2)
                                range2=int(row2["range"])
                                row_2=int(row2["row"])
                                if range1==range2 and rownum==row_2 and exp==field2:
                                    uavdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                    uavdf.at[index1, 'combineYield']=row2["combineYield"]
                                    uavdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                    uavdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                    uavdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                    uavdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                    uavdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                    uavdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                    uavdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                    uavdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                    uavdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                    uavdf.at[index1, 'percentOil']=row2["percentOil"]
                                    uavdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                    uavdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                    uavdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                    uavdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                    uavdf.at[index1, "genotype"]=genotype


                            elif location=='Scottsbluff':
                                # print(file)
                                field=int(file.split("-")[2].split('n')[1])
                                range2=int(row2["range"])
                                row_2=int(row2["row"])
                                # if row2['poundsOfNitrogenPerAcre']

#                                     if math.nan(int(row2['poundsOfNitrogenPerAcre'])):
#                                         continue
                                nitrogen=int(row2['poundsOfNitrogenPerAcre'])
                                # print(nitrogen)
                                if range1==range2 and rownum==row_2 and field==nitrogen:
                                    # print(row2["genotype"])
                                    uavdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                    uavdf.at[index1, 'combineYield']=row2["combineYield"]
                                    uavdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                    uavdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                    uavdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                    uavdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                    uavdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                    uavdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                    uavdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                    uavdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                    uavdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                    uavdf.at[index1, 'percentOil']=row2["percentOil"]
                                    uavdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                    uavdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                    uavdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                    uavdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                    uavdf.at[index1, "genotype"]=genotype
                            elif location=='Lincoln':
                                range2=int(row2["range"])
                                row_2=int(row2["row"])

                                if range1==range2 and rownum==row_2:
                                    uavdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                    uavdf.at[index1, 'combineYield']=row2["combineYield"]
                                    uavdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                    uavdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                    uavdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                    uavdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                    uavdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                    uavdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                    uavdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                    uavdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                    uavdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                    uavdf.at[index1, 'percentOil']=row2["percentOil"]
                                    uavdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                    uavdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                    uavdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                    uavdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                    uavdf.at[index1, "genotype"]=genotype
                                    
                            elif location=='Missouri Valley':
                                range2=int(row2["row"])
                                row_2=int(row2["range"])

                                if range1==range2 and rownum==row_2:
                                    uavdf.at[index1, "plantDensity"]=row2["plantDensity"]
                                    uavdf.at[index1, 'combineYield']=row2["combineYield"]
                                    uavdf.at[index1, 'yieldPerAcre']=row2["yieldPerAcre"]
                                    uavdf.at[index1, 'totalStandCount']=row2["totalStandCount"]
                                    uavdf.at[index1, 'daysToAnthesis']=row2["daysToAnthesis"]
                                    uavdf.at[index1, 'GDDToAnthesis']=row2["GDDToAnthesis"]
                                    uavdf.at[index1, 'daysToSilk']=row2["daysToSilk"]
                                    uavdf.at[index1, 'GDDToSilk']=row2["GDDToSilk"]
                                    uavdf.at[index1, 'percentMoisture']=row2["percentMoisture"]
                                    uavdf.at[index1, 'percentStarch']=row2["percentStarch"]
                                    uavdf.at[index1, 'percentProtein']=row2["percentProtein"]
                                    uavdf.at[index1, 'percentOil']=row2["percentOil"]
                                    uavdf.at[index1, 'percentFiber']=row2["percentFiber"]
                                    uavdf.at[index1, 'percentAsh']=row2["percentAsh"]
                                    uavdf.at[index1, 'percentLodging']=row2["percentLodging"]
                                    uavdf.at[index1, 'flagLeafHeight']=row2["flagLeafHeight"]
                                    uavdf.at[index1, "genotype"]=genotype


                    print(j)
                    uavdf.to_csv(f'{uavfolderpath}/{basename}_genotype.csv', index=False)
# Out:
# location
# Missouri Valley    176
# Name: count, dtype: int64
# sat: SatelliteImage_6bands_TP2.csv
# 1
# sat: SatelliteImage_6bands_TP4.csv
# 2
# sat: SatelliteImage_6bands_TP6.csv
# 3
# sat: SatelliteImage_6bands_TP1.csv
# 4
# sat: SatelliteImage_6bands_TP5.csv
# 5
# sat: SatelliteImage_6bands_TP3.csv
# 6
# UAV: RGBuav_TP2.csv
# 7
# UAV: RGBuav_TP1.csv
# 8
# UAV: RGBuav_TP3.csv
# 9

# %%
datadf_subset['yieldPerAcre'].describe()
# Out:
# count    163.000000
# mean     152.458712
# std       24.298263
# min       89.590000
# 25%      135.895000
# 50%      154.740000
# 75%      167.975000
# max      214.080000
# Name: yieldPerAcre, dtype: float64

# %%
satdf["file_"].str.split('_', expand=True)[0].str.split('-', expand=True)[2]
# Out:
# 0      4231
# 1      4231
# 2      4231
# 3      4231
# 4      4231
#        ...
# 659    4233
# 660    4233
# 661    4233
# 662    4233
# 663    4233
# Name: 2, Length: 664, dtype: object
