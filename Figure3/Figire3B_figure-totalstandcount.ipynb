# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle

import scipy as sp
import numpy as np
from datetime import date
from matplotlib.dates import date2num
# from datetime import date
# from matplotlib.dates import date2num

# %%
Df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/AllTestCorrelation_newversion_totalstandcount_wider_newer.csv', index_col=0)

# %%
Df
# Out:
#                     Ames_TP1  Ames_TP2  Ames_TP3  Ames_TP4  Ames_TP5  \
# testset
# Ames_TP1             0.45952   0.30529   0.18511   0.13278   0.08185
# Ames_TP2             0.18075   0.38105   0.19456   0.15293   0.07719
# Ames_TP3             0.02757   0.12432   0.52706   0.13348   0.02835
# Ames_TP4             0.00924   0.05056   0.12556   0.45910   0.07695
# Ames_TP5             0.00551   0.01023   0.01490   0.03496   0.28376
# Ames_TP6             0.00277   0.00407   0.00081   0.00075   0.01448
# Crawfordsville_TP1   0.01614   0.02992   0.02282   0.01615   0.01442
# Crawfordsville_TP2   0.00316   0.00790   0.00869   0.01105   0.01665
# Crawfordsville_TP3   0.00445   0.00030   0.00058   0.00081   0.00587
# Crawfordsville_TP4   0.00001   0.00005   0.00077   0.00655   0.00539
# Crawfordsville_TP5   0.00484   0.00853   0.00862   0.01025   0.00665
# Crawfordsville_TP6   0.00005   0.00687   0.00850   0.00569   0.00570
# Movalley_TP1         0.33389   0.19765   0.02838   0.00465   0.00670
# Movalley_TP2         0.12588   0.04747   0.00434   0.00019   0.00003
# Movalley_TP3         0.03283   0.03341   0.00386   0.01407   0.01661
# Movalley_TP4         0.01206   0.02465   0.00281   0.00136   0.00000
# Movalley_TP5         0.00353   0.00906   0.00003   0.01304   0.00959
# Movalley_TP6         0.01839   0.02561   0.01513   0.00138   0.00099
#
#                     Ames_TP6  Crawfordsville_TP1  Crawfordsville_TP2  \
# testset
# Ames_TP1             0.05807             0.17247             0.04370
# Ames_TP2             0.03679             0.13868             0.03171
# Ames_TP3             0.01047             0.07313             0.00533
# Ames_TP4             0.00455             0.05300             0.02005
# Ames_TP5             0.02013             0.02021             0.01451
# Ames_TP6             0.31654             0.00400             0.00043
# Crawfordsville_TP1   0.00770             0.33259             0.02566
# Crawfordsville_TP2   0.00241             0.02491             0.31478
# Crawfordsville_TP3   0.00067             0.00254             0.01828
# Crawfordsville_TP4   0.01492             0.01166             0.00793
# Crawfordsville_TP5   0.00007             0.00890             0.00794
# Crawfordsville_TP6   0.00331             0.00719             0.00744
# Movalley_TP1         0.00416             0.06205             0.00073
# Movalley_TP2         0.00596             0.01312             0.00579
# Movalley_TP3         0.00124             0.00731             0.00214
# Movalley_TP4         0.00014             0.00229             0.00233
# Movalley_TP5         0.00005             0.00737             0.01337
# Movalley_TP6         0.01503             0.00811             0.00032
#
#                     Crawfordsville_TP3  Crawfordsville_TP4  \
# testset
# Ames_TP1                       0.07099             0.00399
# Ames_TP2                       0.02624             0.00000
# Ames_TP3                       0.00195             0.01172
# Ames_TP4                       0.00125             0.02123
# Ames_TP5                       0.00150             0.00525
# Ames_TP6                       0.00163             0.00225
# Crawfordsville_TP1             0.00168             0.00474
# Crawfordsville_TP2             0.01302             0.00439
# Crawfordsville_TP3             0.31073             0.00017
# Crawfordsville_TP4             0.00054             0.27679
# Crawfordsville_TP5             0.00015             0.00716
# Crawfordsville_TP6             0.00472             0.00523
# Movalley_TP1                   0.25830             0.05660
# Movalley_TP2                   0.07912             0.03664
# Movalley_TP3                   0.07489             0.00038
# Movalley_TP4                   0.02856             0.00828
# Movalley_TP5                   0.03634             0.00614
# Movalley_TP6                   0.00915             0.00003
#
#                     Crawfordsville_TP5  Crawfordsville_TP6  Movalley_TP1  \
# testset
# Ames_TP1                       0.03624             0.00114       0.21377
# Ames_TP2                       0.03634             0.00544       0.05837
# Ames_TP3                       0.00120             0.00839       0.00033
# Ames_TP4                       0.01982             0.01184       0.00007
# Ames_TP5                       0.01066             0.00617       0.00187
# Ames_TP6                       0.00002             0.00077       0.00233
# Crawfordsville_TP1             0.00832             0.00874       0.00018
# Crawfordsville_TP2             0.00625             0.01689       0.00020
# Crawfordsville_TP3             0.00028             0.00997       0.01637
# Crawfordsville_TP4             0.01859             0.00121       0.00014
# Crawfordsville_TP5             0.33426             0.00020       0.00191
# Crawfordsville_TP6             0.00401             0.29466       0.00579
# Movalley_TP1                   0.02495             0.03642       0.60958
# Movalley_TP2                   0.01563             0.00011       0.22662
# Movalley_TP3                   0.04345             0.00372       0.13875
# Movalley_TP4                   0.00249             0.00019       0.04254
# Movalley_TP5                   0.00603             0.00276       0.03161
# Movalley_TP6                   0.00429             0.00492       0.01741
#
#                     Movalley_TP2  Movalley_TP3  Movalley_TP4  Movalley_TP5  \
# testset
# Ames_TP1                 0.17554       0.08243       0.02458       0.00626
# Ames_TP2                 0.04130       0.02078       0.02454       0.00006
# Ames_TP3                 0.00118       0.00064       0.01283       0.00022
# Ames_TP4                 0.00028       0.00103       0.00000       0.00068
# Ames_TP5                 0.00120       0.00003       0.00019       0.00191
# Ames_TP6                 0.00057       0.00124       0.00017       0.00000
# Crawfordsville_TP1       0.00000       0.00046       0.00011       0.00231
# Crawfordsville_TP2       0.00003       0.00013       0.00000       0.00156
# Crawfordsville_TP3       0.00992       0.00986       0.00329       0.00001
# Crawfordsville_TP4       0.00000       0.00065       0.00082       0.00856
# Crawfordsville_TP5       0.00363       0.01432       0.00054       0.01010
# Crawfordsville_TP6       0.00305       0.00005       0.00667       0.00182
# Movalley_TP1             0.41051       0.32549       0.14379       0.09367
# Movalley_TP2             0.38989       0.18570       0.09985       0.13415
# Movalley_TP3             0.13562       0.49743       0.13105       0.11321
# Movalley_TP4             0.04503       0.07673       0.70130       0.17580
# Movalley_TP5             0.04854       0.09719       0.20577       0.71095
# Movalley_TP6             0.00290       0.02400       0.10685       0.01512
#
#                     Movalley_TP6
# testset
# Ames_TP1                 0.11970
# Ames_TP2                 0.07109
# Ames_TP3                 0.00150
# Ames_TP4                 0.00009
# Ames_TP5                 0.00009
# Ames_TP6                 0.00472
# Crawfordsville_TP1       0.00052
# Crawfordsville_TP2       0.00000
# Crawfordsville_TP3       0.00345
# Crawfordsville_TP4       0.00341
# Crawfordsville_TP5       0.00209
# Crawfordsville_TP6       0.00018
# Movalley_TP1             0.20721
# Movalley_TP2             0.10617
# Movalley_TP3             0.12933
# Movalley_TP4             0.10045
# Movalley_TP5             0.07775
# Movalley_TP6             0.28815

# %%
# Df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Allenvironmentcorrelation_totalstandcount_svm.csv', index_col=0)
# Df

# %%
# Df=Df.pivot_table(index='model',
#               values='r2', columns='testset')
# Df=Df.T
# Df.to_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/AllTestCorrelation_newversion_totalstandcount_wider_newer_svm.csv')

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':2,
    'xtick.major.size':5,
    'ytick.major.size':5,
    'ytick.major.width':2
})



# rcdefaults() 
colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue','Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive'}
custom_ticklabels = ['Movalley_TP1','Movalley_TP2','Movalley_TP3','Movalley_TP4','Movalley_TP5','Movalley_TP6',
                      'Ames_TP1','Ames_TP2','Ames_TP3','Ames_TP4','Ames_TP5','Ames_TP6',
                      'Crawfordsville_TP1','Crawfordsville_TP2','Crawfordsville_TP3','Crawfordsville_TP4','Crawfordsville_TP5','Crawfordsville_TP6']

rearrangeddf=pd.DataFrame(index=custom_ticklabels)
for i in custom_ticklabels:
    tempdf=Df[[str(i)]]
    rearrangeddf=pd.merge(rearrangeddf,tempdf, left_index=True, right_index=True, how='inner')

# reordered_data = [Df[custom_ticklabels.index(label)] for label in reversed(custom_ticklabels)]
plt.figure(figsize=(23,27))
ax=sns.heatmap(rearrangeddf, vmin=-0.75, vmax=0.75, cmap='coolwarm', yticklabels=True, 
            xticklabels=True,cbar_kws={'label': r'Accuracy of Yield Prediction ($R^2$)','format': '%.1f', 'location':'top', "shrink": 0.4})
            # cbar_pos=(-0.6, 0.2, 0.3, 0.4))

yticks=[
r'$\textbf{Missouri Valley}$ July 13', 'July 21', 'August 8', 'September 3', 'September 11', 'September 19',
r'$\textbf{Ames}$ July 15','July 23', 'August 10', 'August 31', 'September 11', 'September 24',
r'$\textbf{Crawfordsville}$ July 10', 'July 20', 'August 2', 'September 13', 'October 1', 'October 9']
ax.set_yticklabels(yticks)
ax.set_xticklabels(yticks)

plt.ylim(-0.5, 18)
plt.xlim(-0.5,18)
ax.tick_params(left=False, bottom=False)

colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue',
          'Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive', 'North Platte':'lightseagreen'}
##horizontal
plt.broken_barh([(0, 6)], (0, -0.5), color="indigo")
plt.broken_barh([(6, 6)], (-0.5, 0.5), color="plum")
plt.broken_barh([(12, 6)], (-0.5, 0.5), color="olive")
# plt.broken_barh([(18, 6)], (-0.5, 0.5), color="plum")
# plt.broken_barh([(24, 6)], (-0.5, 0.5), color="olive")


##vertical
plt.broken_barh([(-0.5, 0.5)], (0, 6), color="indigo")
plt.broken_barh([(-0.5, 0.5)], (6,6), color="plum")
plt.broken_barh([(-0.5, 0.5)], (12,6), color="olive")
# plt.broken_barh([(-0.5, 0.5)], (18,6), color="plum")
# plt.broken_barh([(-0.5, 0.5)], (24,6), color="olive")

# print(plt.yticks())
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.ylabel('Test Dataset')
plt.xlabel('Training Dataset')
plt.savefig('Fiigure3B_totalstandcount_rf.svg',dpi=350,bbox_inches='tight')
plt.show()

# %%
##TotalStandCount

df=pd.read_excel('/home/schnablelab/Documents/NNSatelliteImages/Figure3/FinalCorrelationDates_mean_totalstandcount.xlsx')

df['Date'] = pd.to_datetime(df['Date'])


plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':5,
    'xtick.major.size':7,
    'ytick.major.size':7,
    'xtick.major.width':5,
    'ytick.major.width':5
})
# 

plt.figure(figsize=(22,14))

# ax1=fig.add_subplot(2,1,1)
# df=df.loc[((df['location']=='Missouri Valley') | (df['location']=='Ames')),]
df=df.loc[((df['model']=='RF')),]
# Iterate over unique values of 'location'
for location in df['location'].unique():
    # Subset the data for the current location
    subset = df[df['location'] == location]
    
    # Loop through unique line types for the current location
    for line_type in subset['image'].unique():
        # Subset the data for the current line type
        subset_line_type = subset[subset['image'] == line_type]
        
        if line_type=='Satellite' and location=='Missouri Valley':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'],
                         label=f"{location} - {line_type} Flowering", 
                         linestyle='-', color='indigo',capsize=12, linewidth=6, capthick=6)
        elif line_type=='Satellite' and location=='Ames':
            plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type}",
                         linestyle='-', color='plum',capsize=12,linewidth=6, capthick=6)
        elif line_type=='Satellite' and location=='Crawfordsville':
            plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type}",
                         linestyle='-', color='olive',capsize=12,linewidth=6, capthick=6)
        elif line_type=='UAV'and location=='Missouri Valley':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Post Flowering", 
                         linestyle='--', color='indigo',capsize=12,linewidth=6, capthick=6)
            eb1[-1][0].set_linestyle('--')
        elif line_type=='UAV'and location=='Ames':
            eb2=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Vegetative", 
                         linestyle='--', color='plum',capsize=12,linewidth=6, capthick=6)
            eb2[-1][0].set_linestyle('--')
        elif line_type=='UAV'and location=='Crawfordsville':
            eb3=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Vegetative", 
                         linestyle='--', color='olive',capsize=12,linewidth=6, capthick=6)
            eb3[-1][0].set_linestyle('--')

            
            
handles, labels = plt.gca().get_legend_handles_labels()
order = [4,5,1, 0, 2, 3]  # Define the desired order of legend entries
plt.legend([handles[idx] for idx in order], [labels[idx] for idx in order], title='Location - Image Type', loc='upper center')
ax1=plt.gca()

# yticks=ax1.get_yticks()
# ax1.set_yticklabels([round(x,3) for x in yticks])

plt.ylabel(r'Mean $R^2$ between observed and predicted yield')

# plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A.png', dpi=350)

segments = [(date2num(date(2022, 7, 1)), 9)]
plt.broken_barh(segments,(-0.05, 0.04),color="green")

segments = [(date2num(date(2022, 7, 10)), 23)]
plt.broken_barh(segments,(-0.05, 0.04),color="yellow")

segments = [(date2num(date(2022,8,2)),60)]
plt.broken_barh(segments,(-0.05, 0.04),color="orange")

plt.ylim(-0.05,0.6)
yticks=ax1.get_yticks()
ax1.set_yticklabels([round(x,3) for x in yticks])

months = pd.date_range(start='2022-06-15', end='2022-10-30', freq='MS')
month_nAmes = [date.strftime('%B') for date in months]
plt.xticks(months,month_nAmes)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A_totalstandcount_rf.svg', dpi=350)

plt.show()
# Out:
# /tmp/ipykernel_25363/4186482377.py:90: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels([round(x,3) for x in yticks])

# %%
##UAV heatmap

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':2,
    'xtick.major.size':5,
    'ytick.major.size':5,
    'ytick.major.width':2
})
Df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/AllTestCorrelation_newversion_uav_wider_newer.csv', index_col=0) 
##Already Transposed


# rcdefaults() 
colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue','Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive'}
custom_ticklabels = [ 'Scottsbluff_TP1', 'Scottsbluff_TP2','Scottsbluff_TP3',
                     'Lincoln_TP1','Lincoln_TP2','Lincoln_TP3',
                    'Movalley_TP1','Movalley_TP2','Movalley_TP3',
                      'Ames_TP1','Ames_TP2','Ames_TP3',
                      'Crawfordsville_TP1','Crawfordsville_TP2','Crawfordsville_TP3']

rearrangeddf=pd.DataFrame(index=custom_ticklabels)
for i in custom_ticklabels:
    tempdf=Df[[str(i)]]
    rearrangeddf=pd.merge(rearrangeddf,tempdf, left_index=True, right_index=True, how='inner')

# reordered_data = [Df[custom_ticklabels.index(label)] for label in reversed(custom_ticklabels)]
plt.figure(figsize=(28,32))
ax=sns.heatmap(rearrangeddf, vmin=-0.75, vmax=0.75, cmap='coolwarm', yticklabels=True, 
            xticklabels=True,cbar_kws={'label': r'Accuracy of Yield Prediction ($R^2$)','format': '%.1f', 'location':'top', "shrink": 0.4})
            # cbar_pos=(-0.6, 0.2, 0.3, 0.4))

yticks=[r'$\textbf{Scottsbluff}$ July 8', 'July 22', 'August 12', 
        r'$\textbf{Lincoln}$ July 13', 'July 28', 'August 4',
r'$\textbf{Missouri Valley}$ July 13', 'July 27', 'August 10', 
r'$\textbf{Ames}$ July 12','July 26', 'August 10', 
r'$\textbf{Crawfordsville}$ July 12', 'July 26', 'August 11']
ax.set_yticklabels(yticks)
ax.set_xticklabels(yticks)

plt.ylim(-0.5, 15)
plt.xlim(-0.5,15)
ax.tick_params(left=False, bottom=False)

colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue',
          'Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive', 'North Platte':'lightseagreen'}
##horizontal
plt.broken_barh([(0, 3)], (0, -0.5), color="darkorange")
plt.broken_barh([(3, 3)], (-0.5, 0.5), color="royalblue")
plt.broken_barh([(6, 3)], (-0.5, 0.5), color="indigo")
plt.broken_barh([(9, 3)], (-0.5, 0.5), color="plum")
plt.broken_barh([(12, 3)], (-0.5, 0.5), color="olive")


##vertical
plt.broken_barh([(-0.5, 0.5)], (0, 3), color="darkorange")
plt.broken_barh([(-0.5, 0.5)], (3,3), color="royalblue")
plt.broken_barh([(-0.5, 0.5)], (6,3), color="indigo")
plt.broken_barh([(-0.5, 0.5)], (9,3), color="plum")
plt.broken_barh([(-0.5, 0.5)], (12,3), color="olive")

# print(plt.yticks())
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.ylabel('Test Dataset')
plt.xlabel('Training Dataset')
plt.savefig('Fiigure3B_yieldperacre_UAV.svg',dpi=350,bbox_inches='tight')
plt.show()

# %%
##model performance
grouped_trial=pd.read_excel('FinalCorrelationDates_totalstandcount.xlsx')
grouped_trial

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":12,
    'axes.linewidth':2,
    'xtick.major.size':5,
    'ytick.major.size':5,
    'ytick.major.width':2
})

palette ={"Satellite": "lightgreen", "UAV": "darkgreen"}
ax=sns.barplot(x="model", y="r2", hue="image",  capsize=.1,
            data=grouped_trial, order=['GB','LASSO','LR','PLSR','RF', 'SVM'],
           palette=palette, errorbar='se', errcolor='black', errwidth=1.5)
plt.ylim(0,0.19)
yticks=ax.get_yticks()
ax.set_yticks(yticks)
# print(yticks)
xticks=ax.get_xticklabels()
ax.set_yticklabels([round(x,2) for x in yticks])
plt.ylabel(r'Average Prediction Accuracy ($R^2$)')
plt.legend(title='Image type',frameon=False)
ax.set_xticklabels(labels=xticks,rotation=0)
plt.savefig('AverageAcc_Models_totalstandcount.png', dpi=350,bbox_inches='tight')

plt.show()
