# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle

import scipy as sp
import numpy as np
from datetime import date
from matplotlib.dates import date2num
# from datetime import date
# from matplotlib.dates import date2num

# %%
Df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/AllTestCorrelation_newversion_satellite_wider_newer.csv', index_col=0)

# %%
Df
# Out:
#                     Ames_TP1  Ames_TP2  Ames_TP3  Ames_TP4  Ames_TP5  \
# testset
# Ames_TP1             0.33998   0.04691   0.03495   0.00963   0.00392
# Ames_TP2             0.17947   0.36262   0.19076   0.11843   0.06073
# Ames_TP3             0.31658   0.36048   0.48636   0.30967   0.19411
# Ames_TP4             0.15125   0.25169   0.28641   0.46011   0.33090
# Ames_TP5             0.03596   0.09115   0.10359   0.14736   0.39159
# Ames_TP6             0.00079   0.04237   0.04991   0.04363   0.11212
# Crawfordsville_TP1   0.07677   0.12530   0.11435   0.10761   0.14464
# Crawfordsville_TP2   0.05233   0.11621   0.11873   0.12737   0.09554
# Crawfordsville_TP3   0.07675   0.15582   0.16680   0.17816   0.13849
# Crawfordsville_TP4   0.00693   0.00370   0.02675   0.07500   0.11787
# Crawfordsville_TP5   0.01516   0.00826   0.01197   0.00089   0.01524
# Crawfordsville_TP6   0.09706   0.07561   0.07343   0.02592   0.00364
# ...

# %%
# Df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/AllTestCorrelation_uav.csv', index_col=0)
# Df
# Out:
#                             testset       r2
# model
# Scottsbluff_TP3     Scottsbluff_TP3  0.52910
# Scottsbluff_TP3     Scottsbluff_TP2  0.00114
# Scottsbluff_TP3     Scottsbluff_TP1  0.00949
# Scottsbluff_TP3  Crawfordsville_TP3  0.01001
# Scottsbluff_TP3  Crawfordsville_TP2  0.04466
# ...                             ...      ...
# Ames_TP1               Movalley_TP2  0.09734
# Ames_TP1               Movalley_TP1  0.00167
# Ames_TP1                   Ames_TP3  0.03525
# Ames_TP1                   Ames_TP2  0.00036
# Ames_TP1                   Ames_TP1  0.56026
#
# [225 rows x 2 columns]

# %%
# Df=Df.pivot_table(index='model',
#               values='r2', columns='testset')
# Df=Df.T
# Df.to_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/AllTestCorrelation_newversion_uav_wider_newer.csv')

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':2,
    'xtick.major.size':5,
    'ytick.major.size':5,
    'ytick.major.width':2
})



# rcdefaults() 
colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue','Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive'}
custom_ticklabels = [ 'Scottsbluff_TP1', 'Scottsbluff_TP2','Scottsbluff_TP3','Scottsbluff_TP4','Scottsbluff_TP5','Scottsbluff_TP6',
                     'Lincoln_TP1','Lincoln_TP2','Lincoln_TP3','Lincoln_TP4','Lincoln_TP5','Lincoln_TP6',
                    'Movalley_TP1','Movalley_TP2','Movalley_TP3','Movalley_TP4','Movalley_TP5','Movalley_TP6',
                      'Ames_TP1','Ames_TP2','Ames_TP3','Ames_TP4','Ames_TP5','Ames_TP6',
                      'Crawfordsville_TP1','Crawfordsville_TP2','Crawfordsville_TP3','Crawfordsville_TP4','Crawfordsville_TP5','Crawfordsville_TP6']

rearrangeddf=pd.DataFrame(index=custom_ticklabels)
for i in custom_ticklabels:
    tempdf=Df[[str(i)]]
    rearrangeddf=pd.merge(rearrangeddf,tempdf, left_index=True, right_index=True, how='inner')

# reordered_data = [Df[custom_ticklabels.index(label)] for label in reversed(custom_ticklabels)]
plt.figure(figsize=(23,27))
ax=sns.heatmap(rearrangeddf, vmin=-0.75, vmax=0.75, cmap='coolwarm', yticklabels=True, 
            xticklabels=True,cbar_kws={'label': r'Accuracy of Yield Prediction ($R^2$)','format': '%.1f', 'location':'top', "shrink": 0.4})
            # cbar_pos=(-0.6, 0.2, 0.3, 0.4))

yticks=[r'$\textbf{Scottsbluff}$ July 4', 'July 17', 'August 7', 'August 18', 'September 9', 'September 24',
        r'$\textbf{Lincoln}$ July 18', 'August 6', 'September 3', 'September 11', 'September 19', 'September 27',
r'$\textbf{Missouri Valley}$ July 13', 'July 21', 'August 8', 'September 3', 'September 11', 'September 19',
r'$\textbf{Ames}$ July 15','July 23', 'August 10', 'August 31', 'September 11', 'September 24',
r'$\textbf{Crawfordsville}$ July 10', 'July 20', 'August 2', 'September 13', 'October 1', 'October 9']
ax.set_yticklabels(yticks)
ax.set_xticklabels(yticks)

plt.ylim(-0.5, 30)
plt.xlim(-0.5,30)
ax.tick_params(left=False, bottom=False)

colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue',
          'Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive', 'North Platte':'lightseagreen'}
##horizontal
plt.broken_barh([(0, 6)], (0, -0.5), color="darkorange")
plt.broken_barh([(6, 6)], (-0.5, 0.5), color="royalblue")
plt.broken_barh([(12, 6)], (-0.5, 0.5), color="indigo")
plt.broken_barh([(18, 6)], (-0.5, 0.5), color="plum")
plt.broken_barh([(24, 6)], (-0.5, 0.5), color="olive")


##vertical
plt.broken_barh([(-0.5, 0.5)], (0, 6), color="darkorange")
plt.broken_barh([(-0.5, 0.5)], (6,6), color="royalblue")
plt.broken_barh([(-0.5, 0.5)], (12,6), color="indigo")
plt.broken_barh([(-0.5, 0.5)], (18,6), color="plum")
plt.broken_barh([(-0.5, 0.5)], (24,6), color="olive")

# print(plt.yticks())
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.ylabel('Test Dataset')
plt.xlabel('Training Dataset')
plt.savefig('Fiigure3B_yieldperacre.svg',dpi=350,bbox_inches='tight')
plt.show()

# %%
##yieldperacre

df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/FinalCorrelationDates_mean_newer.csv')

df['Date'] = pd.to_datetime(df['Date'])


plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':5,
    'xtick.major.size':7,
    'ytick.major.size':7,
    'xtick.major.width':5,
    'ytick.major.width':5
})
# 

plt.figure(figsize=(22,14))

# ax1=fig.add_subplot(2,1,1)
df=df.loc[((df['location']=='Missouri Valley') | (df['location']=='Lincoln')),]
df=df.loc[((df['model']=='RF')),]
# Iterate over unique values of 'location'
for location in df['location'].unique():
    # Subset the data for the current location
    subset = df[df['location'] == location]
    
    # Loop through unique line types for the current location
    for line_type in subset['image'].unique():
        # Subset the data for the current line type
        subset_line_type = subset[subset['image'] == line_type]
        
        if line_type=='Satellite' and location=='Missouri Valley':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'],
                         label=f"{location} - {line_type} Flowering", 
                         linestyle='-', color='indigo',capsize=12, linewidth=6, capthick=6)
            
            
        elif line_type=='Satellite' and location=='Lincoln':
            plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type}",
                         linestyle='-', color='royalblue',capsize=12,linewidth=6, capthick=6)
        elif line_type=='UAV'and location=='Missouri Valley':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Post Flowering", 
                         linestyle='--', color='indigo',capsize=12,linewidth=6, capthick=6)
            eb1[-1][0].set_linestyle('--')
        elif line_type=='UAV'and location=='Lincoln':
            eb2=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Vegetative", 
                         linestyle='--', color='royalblue',capsize=12,linewidth=6, capthick=6)
            eb2[-1][0].set_linestyle('--')

            
            
handles, labels = plt.gca().get_legend_handles_labels()
order = [1, 0, 2, 3]  # Define the desired order of legend entries
plt.legend([handles[idx] for idx in order], [labels[idx] for idx in order], title='Location - Image Type', loc='upper center')
ax1=plt.gca()

# yticks=ax1.get_yticks()
# ax1.set_yticklabels([round(x,3) for x in yticks])

plt.ylabel(r'Mean $R^2$ between observed and predicted yield')

# plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A.png', dpi=350)

segments = [(date2num(date(2022, 7, 1)), 9)]
plt.broken_barh(segments,(0, 0.04),color="green")

segments = [(date2num(date(2022, 7, 10)), 23)]
plt.broken_barh(segments,(0, 0.04),color="yellow")

segments = [(date2num(date(2022,8,2)),60)]
plt.broken_barh(segments,(0, 0.04),color="orange")

plt.ylim(0,0.6)
yticks=ax1.get_yticks()
ax1.set_yticklabels([round(x,3) for x in yticks])

months = pd.date_range(start='2022-06-15', end='2022-10-30', freq='MS')
month_nLincoln = [date.strftime('%B') for date in months]
plt.xticks(months,month_nLincoln)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A_latest_bigfont.svg', dpi=350)

plt.show()
# Out:
# /tmp/ipykernel_51349/2011349105.py:83: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels([round(x,3) for x in yticks])

# %%
##TotalStandCount

df=pd.read_excel('/home/schnablelab/Documents/NNSatelliteImages/Figure3/FinalCorrelationDates_mean_totalstandcount.xlsx')

df['Date'] = pd.to_datetime(df['Date'])


plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':5,
    'xtick.major.size':7,
    'ytick.major.size':7,
    'xtick.major.width':5,
    'ytick.major.width':5
})
# 

plt.figure(figsize=(22,14))

# ax1=fig.add_subplot(2,1,1)
df=df.loc[((df['location']=='Missouri Valley') | (df['location']=='Ames')),]
df=df.loc[((df['model']=='RF')),]
# Iterate over unique values of 'location'
for location in df['location'].unique():
    # Subset the data for the current location
    subset = df[df['location'] == location]
    
    # Loop through unique line types for the current location
    for line_type in subset['image'].unique():
        # Subset the data for the current line type
        subset_line_type = subset[subset['image'] == line_type]
        
        if line_type=='Satellite' and location=='Missouri Valley':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'],
                         label=f"{location} - {line_type} Flowering", 
                         linestyle='-', color='indigo',capsize=12, linewidth=6, capthick=6)
            
            
        elif line_type=='Satellite' and location=='Ames':
            plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type}",
                         linestyle='-', color='plum',capsize=12,linewidth=6, capthick=6)
        elif line_type=='UAV'and location=='Missouri Valley':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Post Flowering", 
                         linestyle='--', color='indigo',capsize=12,linewidth=6, capthick=6)
            eb1[-1][0].set_linestyle('--')
        elif line_type=='UAV'and location=='Ames':
            eb2=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Vegetative", 
                         linestyle='--', color='plum',capsize=12,linewidth=6, capthick=6)
            eb2[-1][0].set_linestyle('--')

            
            
handles, labels = plt.gca().get_legend_handles_labels()
order = [1, 0, 2, 3]  # Define the desired order of legend entries
plt.legend([handles[idx] for idx in order], [labels[idx] for idx in order], title='Location - Image Type', loc='upper center')
ax1=plt.gca()

# yticks=ax1.get_yticks()
# ax1.set_yticklabels([round(x,3) for x in yticks])

plt.ylabel(r'Mean $R^2$ between observed and predicted yield')

# plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A.png', dpi=350)

segments = [(date2num(date(2022, 7, 1)), 9)]
plt.broken_barh(segments,(0, 0.04),color="green")

segments = [(date2num(date(2022, 7, 10)), 23)]
plt.broken_barh(segments,(0, 0.04),color="yellow")

segments = [(date2num(date(2022,8,2)),60)]
plt.broken_barh(segments,(0, 0.04),color="orange")

plt.ylim(0,0.6)
yticks=ax1.get_yticks()
ax1.set_yticklabels([round(x,3) for x in yticks])

months = pd.date_range(start='2022-06-15', end='2022-10-30', freq='MS')
month_nAmes = [date.strftime('%B') for date in months]
plt.xticks(months,month_nAmes)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A_latest_bigfont_totalstandcount.svg', dpi=350)

plt.show()
# Out:
# /tmp/ipykernel_42741/3137857009.py:83: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels([round(x,3) for x in yticks])

# %%
##Alllocation Supplementray file


df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/FinalCorrelationDates_mean_newer.csv')

df['Date'] = pd.to_datetime(df['Date'])


plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':5,
    'xtick.major.size':7,
    'ytick.major.size':7,
    'xtick.major.width':5,
    'ytick.major.width':5
})
# 

plt.figure(figsize=(22,14))
colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue',
          'Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive', 'North Platte':'lightseagreen'}
# ax1=fig.add_subplot(2,1,1)
# df=df.loc[((df['location']=='Missouri Valley') | (df['location']=='Lincoln')),]
df=df.loc[((df['model']=='RF')),]
# Iterate over unique values of 'location'
for location in df['location'].unique():
    # Subset the data for the current location
    subset = df[df['location'] == location]
    
    # Loop through unique line types for the current location
    for line_type in subset['image'].unique():
        # Subset the data for the current line type
        subset_line_type = subset[subset['image'] == line_type]
        
        if line_type=='Satellite' and location=='Scottsbluff':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'],
                         label=f"{location} - {line_type} Flowering", 
                         linestyle='-', color='darkorange',capsize=12, linewidth=6, capthick=6)
        elif line_type=='Satellite' and location=='Ames':
            plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type}",
                         linestyle='-', color='plum',capsize=12,linewidth=6, capthick=6)
        elif line_type=='Satellite' and location=='Crawfordsville':
            plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type}",
                         linestyle='-', color='olive',capsize=12,linewidth=6, capthick=6)
        elif line_type=='UAV'and location=='Scottsbluff':
            eb1=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Post Flowering", 
                         linestyle='--', color='darkorange',capsize=12,linewidth=6, capthick=6)
            eb1[-1][0].set_linestyle('--')
        elif line_type=='UAV'and location=='Ames':
            eb2=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Vegetative", 
                         linestyle='--', color='plum',capsize=12,linewidth=6, capthick=6)
            eb2[-1][0].set_linestyle('--')
        elif line_type=='UAV'and location=='Crawfordsville':
            eb3=plt.errorbar(subset_line_type['Date'], subset_line_type['r2_mean'], 
                         yerr=subset_line_type['r2_se'], label=f"{location} - {line_type} Vegetative", 
                         linestyle='--', color='olive',capsize=12,linewidth=6, capthick=6)
            eb3[-1][0].set_linestyle('--')

            
            
handles, labels = plt.gca().get_legend_handles_labels()
print(handles, labels )
order = [4,5,1, 0, 2, 3]  # Define the desired order of legend entries
plt.legend([handles[idx] for idx in order], [labels[idx] for idx in order], loc='upper center')
ax1=plt.gca()

# yticks=ax1.get_yticks()
# ax1.set_yticklabels([round(x,3) for x in yticks])

plt.ylabel(r'Mean $R^2$ between observed and predicted yield')

# plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A.png', dpi=350)

segments = [(date2num(date(2022, 7, 1)), 9)]
plt.broken_barh(segments,(0, 0.04),color="green")

segments = [(date2num(date(2022, 7, 10)), 23)]
plt.broken_barh(segments,(0, 0.04),color="yellow")

segments = [(date2num(date(2022,8,2)),60)]
plt.broken_barh(segments,(0, 0.04),color="orange")

plt.ylim(0,0.5)
yticks=ax1.get_yticks()
ax1.set_yticklabels([round(x,3) for x in yticks])

months = pd.date_range(start='2022-06-15', end='2022-10-30', freq='MS')
month_nLincoln = [date.strftime('%B') for date in months]
plt.xticks(months,month_nLincoln)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

plt.savefig('/home/schnablelab/Documents/NNSatelliteImages/Figure3/Figure3A_latest_bigfont_yield_supplementary.svg', dpi=350)

plt.show()
# Out:
# [<ErrorbarContainer object of 3 artists>, <ErrorbarContainer object of 3 artists>, <ErrorbarContainer object of 3 artists>, <ErrorbarContainer object of 3 artists>, <ErrorbarContainer object of 3 artists>, <ErrorbarContainer object of 3 artists>] ['Scottsbluff - Satellite Flowering', 'Scottsbluff - UAV Post Flowering', 'Crawfordsville - Satellite', 'Crawfordsville - UAV Vegetative', 'Ames - Satellite', 'Ames - UAV Vegetative']
# /tmp/ipykernel_51349/2578601367.py:93: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels([round(x,3) for x in yticks])

# %%
##UAV heatmap

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":40,
    'axes.linewidth':2,
    'xtick.major.size':5,
    'ytick.major.size':5,
    'ytick.major.width':2
})
Df=pd.read_csv('/home/schnablelab/Documents/NNSatelliteImages/Figure3/AllTestCorrelation_newversion_uav_wider_newer.csv', index_col=0) 
##Already Transposed


# rcdefaults() 
colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue','Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive'}
custom_ticklabels = [ 'Scottsbluff_TP1', 'Scottsbluff_TP2','Scottsbluff_TP3',
                     'Lincoln_TP1','Lincoln_TP2','Lincoln_TP3',
                    'Movalley_TP1','Movalley_TP2','Movalley_TP3',
                      'Ames_TP1','Ames_TP2','Ames_TP3',
                      'Crawfordsville_TP1','Crawfordsville_TP2','Crawfordsville_TP3']

rearrangeddf=pd.DataFrame(index=custom_ticklabels)
for i in custom_ticklabels:
    tempdf=Df[[str(i)]]
    rearrangeddf=pd.merge(rearrangeddf,tempdf, left_index=True, right_index=True, how='inner')

# reordered_data = [Df[custom_ticklabels.index(label)] for label in reversed(custom_ticklabels)]
plt.figure(figsize=(28,32))
ax=sns.heatmap(rearrangeddf, vmin=-0.75, vmax=0.75, cmap='coolwarm', yticklabels=True, 
            xticklabels=True,cbar_kws={'label': r'Accuracy of Yield Prediction ($R^2$)','format': '%.1f', 'location':'top', "shrink": 0.4})
            # cbar_pos=(-0.6, 0.2, 0.3, 0.4))

yticks=[r'$\textbf{Scottsbluff}$ July 8', 'July 22', 'August 12', 
        r'$\textbf{Lincoln}$ July 13', 'July 28', 'August 4',
r'$\textbf{Missouri Valley}$ July 13', 'July 27', 'August 10', 
r'$\textbf{Ames}$ July 12','July 26', 'August 10', 
r'$\textbf{Crawfordsville}$ July 12', 'July 26', 'August 11']
ax.set_yticklabels(yticks)
ax.set_xticklabels(yticks)

plt.ylim(-0.5, 15)
plt.xlim(-0.5,15)
ax.tick_params(left=False, bottom=False)

colors = {'Scottsbluff':'darkorange','Lincoln':'royalblue',
          'Missouri Valley':'indigo','Ames':'plum', 'Crawfordsville':'olive', 'North Platte':'lightseagreen'}
##horizontal
plt.broken_barh([(0, 3)], (0, -0.5), color="darkorange")
plt.broken_barh([(3, 3)], (-0.5, 0.5), color="royalblue")
plt.broken_barh([(6, 3)], (-0.5, 0.5), color="indigo")
plt.broken_barh([(9, 3)], (-0.5, 0.5), color="plum")
plt.broken_barh([(12, 3)], (-0.5, 0.5), color="olive")


##vertical
plt.broken_barh([(-0.5, 0.5)], (0, 3), color="darkorange")
plt.broken_barh([(-0.5, 0.5)], (3,3), color="royalblue")
plt.broken_barh([(-0.5, 0.5)], (6,3), color="indigo")
plt.broken_barh([(-0.5, 0.5)], (9,3), color="plum")
plt.broken_barh([(-0.5, 0.5)], (12,3), color="olive")

# print(plt.yticks())
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.ylabel('Test Dataset')
plt.xlabel('Training Dataset')
plt.savefig('Fiigure3B_yieldperacre_UAV.svg',dpi=350,bbox_inches='tight')
plt.show()

# %%
##model performance
grouped_trial=pd.read_excel('FinalCorrelationDates.xlsx')
grouped_trial

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Nimbus Sans",
    "font.size":12,
    'axes.linewidth':2,
    'xtick.major.size':5,
    'ytick.major.size':5,
    'ytick.major.width':2
})

palette ={"Satellite": "lightgreen", "UAV": "darkgreen"}
ax=sns.barplot(x="model", y="r2", hue="image",  capsize=.1,
            data=grouped_trial, order=['GB','LASSO','LR','PLSR','RF', 'SVM'],
           palette=palette, errorbar='se', errcolor='black', errwidth=1.5)
plt.ylim(0,0.3)
yticks=ax.get_yticks()
ax.set_yticks(yticks)
# print(yticks)
xticks=ax.get_xticklabels()
ax.set_yticklabels([round(x,2) for x in yticks])
plt.ylabel(r'Average Prediction Accuracy ($R^2$)')
plt.legend(title='Image type',frameon=False)
ax.set_xticklabels(labels=xticks,rotation=0)
# plt.savefig('AverageAcc_Models.png', dpi=350,bbox_inches='tight')

plt.show()

# %%
grouped_trial
# Out:
#      time     location  model      image        r2  rep      Location  \
# 0     TP1  Scottsbluff     RF  Satellite  0.053561  1.0   Scottsbluff
# 1     TP1  Scottsbluff   PLSR  Satellite  0.000290  1.0   Scottsbluff
# 2     TP1  Scottsbluff     LR  Satellite  0.084399  1.0   Scottsbluff
# 3     TP1  Scottsbluff  LASSO  Satellite       NaN  1.0   Scottsbluff
# 4     TP1  Scottsbluff    SVM  Satellite  0.043531  1.0   Scottsbluff
# ...   ...          ...    ...        ...       ...  ...           ...
# 1354  TP5          NaN    NaN        NaN       NaN  NaN  North Platte
# 1355  TP6          NaN    NaN        NaN       NaN  NaN  North Platte
# 1356  TP1          NaN    NaN        NaN       NaN  NaN  North Platte
# 1357  TP2          NaN    NaN        NaN       NaN  NaN  North Platte
# 1358  TP3          NaN    NaN        NaN       NaN  NaN  North Platte
#
#            Date      Image
# 0    2022-07-04  Satellite
# 1    2022-07-04  Satellite
# 2    2022-07-04  Satellite
# ...
